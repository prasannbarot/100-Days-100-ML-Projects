# %%
# Cell 2: Run scraper
# !python scripts/scraper.py

# Cell 3: Process data
# !python scripts/data_processor.py

# Cell 4: Train model
# !python scripts/ml_predictor.py

# Cell 5: View alerts
# !python scripts/alerts.py

# Cell 6: Launch dashboard
# !streamlit run web_app/app.py
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Scraping What Are Your Moves Tomorrow, February 03, 2026
# Scraping Daily Discussion Thread for February 02, 2026
# Scraping What Are Your Moves Tomorrow, February 02, 2026
# Comment error 1qtajzr: HTTPSConnectionPool(host='www.reddit.com', port=443): Max retries exceeded with url: /comments/1qtajzr.json?raw_json=1 (Caused by ConnectTimeoutError(<HTTPSConnection(host='www.reddit.com', port=443) at 0x1c35df32ad0>, 'Connection to www.reddit.com timed out. (connect timeout=None)'))
# Scraping Daily Discussion Thread for January 30, 2026
# Scraping What Are Your Moves Tomorrow, January 30, 2026
# Scraping Daily Discussion Thread for January 29, 2026
# Scraping What Are Your Moves Tomorrow, January 29, 2026
# Scraping Daily Discussion Thread for January 28, 2026
# Scraping What Are Your Moves Tomorrow, January 28, 2026
# Scraping Daily Discussion Thread for January 27, 2026
# Scraping What Are Your Moves Tomorrow, January 27, 2026
# Scraping Daily Discussion Thread for January 26, 2026
# Saved 1106 comments
# Processed sentiment saved
# Model trained and saved
# 🚀 ALERT: Strong positive sentiment → Expected upward move (3.6%)
# c:\Users\jinal\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ^C
